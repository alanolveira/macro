# %% [markdown]
# <a href="https://colab.research.google.com/github/alanolveira/macro/blob/main/provamacroI_infla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt #import library for plotting graphs

# %%
mês =  ['abril.20', 'maio.20', 'junho.20', 'julho.20', 'agosto.20', 'setembro.20'
      'outubro.20', 'novembro.20', 'dezembro.20', 'janeiro.21', 'fevereiro.21', 'março.21]

# %%
IPCA_mensal = [-0.31, -0.38, 0.26, 0.36, 0.24, 0.64, 0.86, 0.89, 1.35, 0.25, 0.86, 0.93]

# %%
taxa_selic = [3.75, 3.00, 3.00, 2.25, 2.00, 2.00, 2.00, 2.00, 2.00, 2.00, 2.00, 2.75]

# %%
inflação_mensal = [2.40, 1.88, 2.13, 2.31, 2.44, 3.14, 3.92, 4.31, 4.52, 4.56, 5.20, 6.10]

# %%
fig, ax = plt.subplots(figsize = (16, 8))
plt.plot (mês, taxa_selic, inflação_mensal)
plt.title ('taxas mensal')
plt.xlabel ('mês')
plt.ylabel ('taxa_selic, inflação_mensal')
plt.show()
